# %% [markdown]
# # 通过字典创建数据集

# %%
import os
from datasets import Dataset, Image

file_path = r'E:\Desktop\data\edit_start'

file_dict = {}
file_dict['image'] = []
for i in os.listdir(file_path):
    path =os.path.join(file_path,i)
    file_dict['image'].append(path)

dataset = Dataset.from_dict(file_dict).cast_column('image',Image())
print(dataset[0])
# Out:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x1024 at 0x281FA37C260>}

# %%
dataset
# Out:
# Dataset({
#     features: ['image'],
#     num_rows: 300
# })

# %% [markdown]
# # 通过文件夹创建数据集

# %%
from datasets import load_dataset

image_gen = r'E:\Desktop\data\图像生成'

dataset = load_dataset("imagefolder", data_dir=image_gen, split="train")
# Out:
# Resolving data files:   0%|          | 0/600 [00:00<?, ?it/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['image'],
#     num_rows: 300
# })
